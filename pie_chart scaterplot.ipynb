# %% [markdown]
# <a href="https://colab.research.google.com/github/Muppudathiselvam1/Dataset/blob/main/pie_chart%20scaterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
#pie chart
#a=[56,25,10]
#plt.pie(a,labels=['salt waater','hima_water','drinking_water'],autopct='%1.1f%%', shadow=True,explode=[0.1,0.1,0.1],startangle=90)
#plt.show()

# #scaterplot
# time=[1,2,3,4]
# mark=[10,20,30,40]
# #negative
# mark=[50,40,30,10]
# #no corelated
# mark=[50,530,20,60]
# #sales=[100,200,300,400]
# #profit=[10,20,30,40]
# plt.scatter(time,mark)
# plt.show()
